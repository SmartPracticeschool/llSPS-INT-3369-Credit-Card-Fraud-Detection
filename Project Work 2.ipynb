# %% [markdown]
# # CREDIT CARD FRAUD DETECTION

# %% [markdown]
# The main goal of building this MACHINE LEARNING MODEL is that the Credit Card Companies shall be able to recognize fraudulent so that the customers are not charged for items that they didn't purchase.

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Importing Dataset

# %%
credit_card=pd.read_csv("310_23498_compressed_creditcard.csv.zip")
credit_card
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# The dataset contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.

# %%
type(credit_card)
# Out:
# pandas.core.frame.DataFrame

# %%
columns=print(credit_card.columns)
columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
z=credit_card.shape
print("Dimension of the given dataset is : ",z)
# Out:
# Dimension of the given dataset is :  (284807, 31)

# %%
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# # Checking Null/Missing Values

# %%
credit_card.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
credit_card.drop(credit_card.columns[[13,15,22,23,24,25,26]],axis=1,inplace=True)

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 24 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V14     284807 non-null  float64
#  14  V16     284807 non-null  float64
#  15  V17     284807 non-null  float64
#  16  V18     284807 non-null  float64
#  17  V19     284807 non-null  float64
#  18  V20     284807 non-null  float64
#  19  V21     284807 non-null  float64
# ...

# %% [markdown]
# # Data Visualization

# %%
count=credit_card["Class"].value_counts()
count
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.countplot(credit_card["Class"],label="count")

# %%
credit_card.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(credit_card.corr(),annot=True)
plt.title("Correlation between independent and dependent variables")
# Out:
# Text(0.5, 1, 'Correlation between independent and dependent variables')

# %%
features = ['V%d' % number for number in range(1,13)] + ['V14']+['V%d' % number for number in range(16,22)] + ['V27']+['V28']+['Amount']
label = 'Class'
a = credit_card[features]
b = credit_card[label]
a.hist(figsize = (20, 20))
plt.show()

# %% [markdown]
# # Separating Dependent and Independent Variables

# %%
x=credit_card.iloc[:,0:23].values
x
# Out:
# array([[ 0.00000000e+00, -1.35980713e+00, -7.27811733e-02, ...,
#          1.33558377e-01, -2.10530535e-02,  1.49620000e+02],
#        [ 0.00000000e+00,  1.19185711e+00,  2.66150712e-01, ...,
#         -8.98309914e-03,  1.47241692e-02,  2.69000000e+00],
#        [ 1.00000000e+00, -1.35835406e+00, -1.34016307e+00, ...,
#         -5.53527940e-02, -5.97518406e-02,  3.78660000e+02],
#        ...,
#        [ 1.72788000e+05,  1.91956501e+00, -3.01253846e-01, ...,
#          4.45477214e-03, -2.65608286e-02,  6.78800000e+01],
#        [ 1.72788000e+05, -2.40440050e-01,  5.30482513e-01, ...,
#          1.08820735e-01,  1.04532821e-01,  1.00000000e+01],
#        [ 1.72792000e+05, -5.33412522e-01, -1.89733337e-01, ...,
#         -2.41530880e-03,  1.36489143e-02,  2.17000000e+02]])

# %%
y=credit_card.iloc[:,23].values
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
x.shape
# Out:
# (284807, 23)

# %%
y.shape
# Out:
# (284807,)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.99658302, -0.69424232, -0.04407492, ...,  0.33089162,
#         -0.06378115,  0.24496426],
#        [-1.99658302,  0.60849633,  0.16117592, ..., -0.02225568,
#          0.04460752, -0.34247454],
#        [-1.99656197, -0.69350046, -0.81157783, ..., -0.13713686,
#         -0.18102083,  1.16068593],
#        ...,
#        [ 1.6419735 ,  0.98002374, -0.18243372, ...,  0.01103672,
#         -0.0804672 , -0.0818393 ],
#        [ 1.6419735 , -0.12275539,  0.32125034, ...,  0.26960398,
#          0.31668678, -0.31324853],
#        [ 1.64205773, -0.27233093, -0.11489898, ..., -0.00598394,
#          0.04134999,  0.51435531]])

# %%
from joblib import dump
dump(sc,"detection.save")
# Out:
# ['detection.save']

# %% [markdown]
# # Splitting Train and Test Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Application of Algorithms

# %% [markdown]
# Here, we have an output to be predicted so it comes under "SUPERVISED LEARNING" and since the output is categorical we use "Classification Algorithms".

# %% [raw]
# Here,I have got the following accuracy values for different classification alogorithms:
#     Logistic Regression   :0.999192
#     Decision Tree         :0.999297
#     Random Forest         :0.999455
#     K Nearest Neighbors   :0.999455
#     Naive Bayes           :0.979301
#     Support Vector Machine:0.999315
#
# But, here I got 0.99 accuracy for all the algorithms which might result in overfitting except for Naive Bayes.
# So, we consider Naive Bayes Algorithm so as to get best accurate model

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
import pickle
pickle.dump(gnb,open('naive_bayes.pkl','wb'))

# %%
y_pred=gnb.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# By comparing,y_test and y_pred values ,we observe that almost all the values are correctly predicted.

# %% [markdown]
# # Evaluating the Performance of the Model:

# %% [markdown]
# 1. Calculation of Accuracy:

# %%
from sklearn.metrics import accuracy_score
A=accuracy_score(y_test,y_pred)
print("Accuracy of the Model:",A )
# Out:
# Accuracy of the Model: 0.9793019908008848

# %% [markdown]
# CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[55697,  1164],
#        [   15,    86]], dtype=int64)

# %% [markdown]
# 2. AUC-ROC Curve:

# %%
import sklearn.metrics as metrics
fpr,tpr,threshold=metrics.roc_curve(y_test,y_pred)
roc_auc=metrics.auc(fpr,tpr)
roc_auc
# Out:
# 0.9155070877200803

# %%
plt.title("Receiver Operator Characteristics")
plt.plot(fpr,tpr,'c',label="AUC=%0.2f")
plt.legend(loc="upper left")
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>
